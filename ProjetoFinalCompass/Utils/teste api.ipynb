# %%
import json
import pandas as pd
import requests

# %%
endereco = r'C:\RPA\RPA_Valor_de_Cotacao\ProjetoFinalCompass\Processados\dados.json'

# %%
df = pd.read_excel(r"C:\RPA\RPA_Valor_de_Cotacao\ProjetoFinalCompass\Processar\Planilha de Entrada Grupos.xlsx")

# %%
lista_cnpj = []
for cnpj in df['CNPJ']:
    if len(str(cnpj)) == 13:
        lista_cnpj.append("0" + str(cnpj))
    else:
        lista_cnpj.append(str(cnpj))

# %%
request_list = []

for cnpj in lista_cnpj:
    url = f"https://brasilapi.com.br/api/cnpj/v1/{cnpj}"
    response = requests.get(url)
    request_list.append(response.json())

# %%
df2 = pd.DataFrame(request_list)
colunas = ["cnpj", "razao_social", "nome_fantasia", "situacao_cadastral", "logradouro", "numero", "municipio", "cep", "descricao_identificador_matriz_filial", "ddd_telefone_1", "email"]

df3 = df2[colunas].copy()

df3 = df3.dropna(subset=['cnpj']).reset_index(drop=True)

df3 = df3.fillna("N/A")
df3 = df3.replace("", "N/A")

# %%
df3
# Out:
#               cnpj                                       razao_social  \
# 0   02828446000134                        0001A LITORAL LOCADORA LTDA
# 1   72610132000146                    0001 ASSESSORIA E SERVICOS LTDA
# 2   01874354000128                 0002 RESTAURANTE E LANCHONETE LTDA
# 3   04220692000134               0009 CHURRASCARIA E RESTAURANTE LTDA
# 4   26159125000152                                  001 AUTO CAR LTDA
# 5   12146377000132                            001 A & W PIZZARIA LTDA
# 6   06034513000108  001 - M & C SERVICOS DE XEROX E ENCADERNACOES ...
# 7   02006030000130                  001MELHOR GESTAO EMPRESARIAL LTDA
# 8   10467359000127                            MEGA FEIRA BETANIA LTDA
# 9   13080788000135                    001 PERFUMES E INFORMATICA LTDA
# 10  15358677000173     001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA
#
#                                     nome_fantasia  situacao_cadastral  \
# 0                                LITORAL LOCADORA                 8.0
# 1                                          PROLAR                 8.0
# 2                                   SANDUBA GRILL                 8.0
# 3                                      FAST GRILL                 4.0
# 4                                             N/A                 4.0
# 5                                         SABORES                 8.0
# 6                                        ALUMIVAL                 4.0
# 7               001SHOPNET TECNICAS E TECNOLOGIAS                 2.0
# 8   MEGA FEIRA BETANIA - ADMINISTRACAO E PROMOCAO                 4.0
# 9                                             N/A                 4.0
# 10                                   001SHOP LTDA                 8.0
#
#                       logradouro numero           municipio       cep  \
# 0                   OSWALDO CRUZ    211            SALVADOR  41940000
# 1          SCS QUADRA 01 BLOCO M     30            BRASILIA  70310500
# 2         MUN SAO JOAO DE MERITI    111  SAO JOAO DE MERITI  25510292
# 3   MUNICIPAL SAO JOAO DE MERITI    111  SAO JOAO DE MERITI  25569900
# 4                COELHO DA ROCHA    940            MESQUITA  26574390
# 5           PLINIO BRASIL MILANO   2244        PORTO ALEGRE  90520001
# 6                      SAQUAREMA   2850           SAQUAREMA  28993000
# 7              RIO GRANDE DO SUL     54      BELO HORIZONTE  30170110
# 8                 URSULA PAULINO   1686      BELO HORIZONTE  30580003
# 9                 PADRE ANCHIETA   1995            CURITIBA  80730000
# 10          LUIZ RONALDO CANALLI   3235            CURITIBA  81230162
#
#    descricao_identificador_matriz_filial ddd_telefone_1 email
# 0                                 MATRIZ     7132406044   N/A
# 1                                 MATRIZ            N/A   N/A
# 2                                 MATRIZ            N/A   N/A
# 3                                 MATRIZ            N/A   N/A
# 4                                 MATRIZ     2137669710   N/A
# 5                                 MATRIZ     5133256060   N/A
# 6                                 MATRIZ     2132460772   N/A
# 7                                 MATRIZ     3199746221   N/A
# 8                                 MATRIZ     3133832800   N/A
# 9                                 MATRIZ     4132246237   N/A
# 10                                MATRIZ     4130393216   N/A

# %%
mapa = {1: "Nula", 2: "Ativa", 3: "Suspensa", 4: "Inapta", 5: "Ativa Não Regular", 8: "Baixada"}

df3["situacao_cadastral"] = df3["situacao_cadastral"].map(mapa)

df3.columns = ["CNPJ", "Razão Social", "Nome Fantasia", "Situação Cadastral", "Logradouro", "Numero", "Município", "CEP", "Matriz ou Filial", "DDD e Telefone", "Email"]

# %%
df3
# Out:
#               CNPJ                                       Razão Social  \
# 0   02828446000134                        0001A LITORAL LOCADORA LTDA
# 1   72610132000146                    0001 ASSESSORIA E SERVICOS LTDA
# 2   01874354000128                 0002 RESTAURANTE E LANCHONETE LTDA
# 3   04220692000134               0009 CHURRASCARIA E RESTAURANTE LTDA
# 4   26159125000152                                  001 AUTO CAR LTDA
# 5   12146377000132                            001 A & W PIZZARIA LTDA
# 6   06034513000108  001 - M & C SERVICOS DE XEROX E ENCADERNACOES ...
# 7   02006030000130                  001MELHOR GESTAO EMPRESARIAL LTDA
# 8   10467359000127                            MEGA FEIRA BETANIA LTDA
# 9   13080788000135                    001 PERFUMES E INFORMATICA LTDA
# 10  15358677000173     001SHOP DESENVOLVIMENTO DE LOJAS VIRTUAIS LTDA
#
#                                     Nome Fantasia Situação Cadastral  \
# 0                                LITORAL LOCADORA            Baixada
# 1                                          PROLAR            Baixada
# 2                                   SANDUBA GRILL            Baixada
# 3                                      FAST GRILL             Inapta
# 4                                             N/A             Inapta
# 5                                         SABORES            Baixada
# 6                                        ALUMIVAL             Inapta
# 7               001SHOPNET TECNICAS E TECNOLOGIAS              Ativa
# 8   MEGA FEIRA BETANIA - ADMINISTRACAO E PROMOCAO             Inapta
# 9                                             N/A             Inapta
# 10                                   001SHOP LTDA            Baixada
#
#                       Logradouro Numero           Município       CEP  \
# 0                   OSWALDO CRUZ    211            SALVADOR  41940000
# 1          SCS QUADRA 01 BLOCO M     30            BRASILIA  70310500
# 2         MUN SAO JOAO DE MERITI    111  SAO JOAO DE MERITI  25510292
# 3   MUNICIPAL SAO JOAO DE MERITI    111  SAO JOAO DE MERITI  25569900
# 4                COELHO DA ROCHA    940            MESQUITA  26574390
# 5           PLINIO BRASIL MILANO   2244        PORTO ALEGRE  90520001
# 6                      SAQUAREMA   2850           SAQUAREMA  28993000
# 7              RIO GRANDE DO SUL     54      BELO HORIZONTE  30170110
# 8                 URSULA PAULINO   1686      BELO HORIZONTE  30580003
# 9                 PADRE ANCHIETA   1995            CURITIBA  80730000
# 10          LUIZ RONALDO CANALLI   3235            CURITIBA  81230162
#
#    Matriz ou Filial DDD e Telefone Email
# 0            MATRIZ     7132406044   N/A
# 1            MATRIZ            N/A   N/A
# 2            MATRIZ            N/A   N/A
# 3            MATRIZ            N/A   N/A
# 4            MATRIZ     2137669710   N/A
# 5            MATRIZ     5133256060   N/A
# 6            MATRIZ     2132460772   N/A
# 7            MATRIZ     3199746221   N/A
# 8            MATRIZ     3133832800   N/A
# 9            MATRIZ     4132246237   N/A
# 10           MATRIZ     4130393216   N/A

# %%
cnpj_ausentes = [cnpj for cnpj in lista_cnpj if cnpj not in df3["CNPJ"].tolist()]
print(cnpj_ausentes)
# Out:
# ['87640321000139', '75196348000103', '86937045000102', '95082173000102']

# %%
df3.to_csv(r"C:\RPA\RPA_Valor_de_Cotacao\ProjetoFinalCompass\Processados\dados_processados", index=False)
